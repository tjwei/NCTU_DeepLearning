# %% [markdown]
# <a href="https://colab.research.google.com/github/tjwei/NCTU_DeepLearning/blob/master/tf2_tutorial/01_Quick_Start.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow-gpu==2.0.0-rc1
# Out:
# Requirement already satisfied: tensorflow-gpu==2.0.0-rc1 in /usr/local/lib/python3.6/dist-packages (2.0.0rc1)
# Requirement already satisfied: tb-nightly<1.15.0a20190807,>=1.15.0a20190806 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-rc1) (1.15.0a20190806)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-rc1) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-rc1) (0.1.7)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-rc1) (1.11.2)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-rc1) (0.33.6)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-rc1) (1.16.5)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-rc1) (0.2.2)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-rc1) (1.12.0)
# Requirement already satisfied: tf-estimator-nightly<1.14.0.dev2019080602,>=1.14.0.dev2019080601 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-rc1) (1.14.0.dev2019080601)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-rc1) (3.0.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-rc1) (1.15.0)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-rc1) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-rc1) (1.1.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-rc1) (3.7.1)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-rc1) (0.8.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-rc1) (0.8.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.15.0a20190807,>=1.15.0a20190806->tensorflow-gpu==2.0.0-rc1) (41.2.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.15.0a20190807,>=1.15.0a20190806->tensorflow-gpu==2.0.0-rc1) (0.15.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.15.0a20190807,>=1.15.0a20190806->tensorflow-gpu==2.0.0-rc1) (3.1.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu==2.0.0-rc1) (2.8.0)

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.0.0-rc1'

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
x_train.shape, x_train.dtype
# Out:
# ((60000, 28, 28), dtype('uint8'))

# %%
y_train.shape, y_train.dtype
# Out:
# ((60000,), dtype('uint8'))

# %%
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

# %%
from PIL import Image
Image.fromarray(x_train[0])
# Out:
# <PIL.Image.Image image mode=L size=28x28 at 0x7F3B1B6843C8>

# %%
x_train = (x_train-127.5)/127.5
x_test = (x_test-127.5)/127.5

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')    
])

# %%
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_8 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 128)               100480
# _________________________________________________________________
# dense_17 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
#optimizer = tf.keras.optimizers.SGD(learning_rate=1e-1)
model.compile(optimizer="sgd", loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 7s 121us/sample - loss: 0.4668 - accuracy: 0.8655 - val_loss: 0.3042 - val_accuracy: 0.9133
# Epoch 2/10
# 60000/60000 [==============================] - 8s 125us/sample - loss: 0.2841 - accuracy: 0.9180 - val_loss: 0.2454 - val_accuracy: 0.9273
# Epoch 3/10
# 60000/60000 [==============================] - 7s 122us/sample - loss: 0.2357 - accuracy: 0.9317 - val_loss: 0.2155 - val_accuracy: 0.9371
# Epoch 4/10
# 60000/60000 [==============================] - 7s 117us/sample - loss: 0.2023 - accuracy: 0.9420 - val_loss: 0.1888 - val_accuracy: 0.9446
# Epoch 5/10
# 60000/60000 [==============================] - 7s 116us/sample - loss: 0.1779 - accuracy: 0.9488 - val_loss: 0.1744 - val_accuracy: 0.9490
# Epoch 6/10
# 60000/60000 [==============================] - 7s 118us/sample - loss: 0.1589 - accuracy: 0.9547 - val_loss: 0.1555 - val_accuracy: 0.9556
# Epoch 7/10
# 60000/60000 [==============================] - 7s 117us/sample - loss: 0.1444 - accuracy: 0.9588 - val_loss: 0.1464 - val_accuracy: 0.9581
# Epoch 8/10
# 60000/60000 [==============================] - 7s 117us/sample - loss: 0.1318 - accuracy: 0.9624 - val_loss: 0.1387 - val_accuracy: 0.9600
# Epoch 9/10
# 60000/60000 [==============================] - 7s 117us/sample - loss: 0.1221 - accuracy: 0.9650 - val_loss: 0.1272 - val_accuracy: 0.9637
# Epoch 10/10
# 60000/60000 [==============================] - 7s 117us/sample - loss: 0.1134 - accuracy: 0.9681 - val_loss: 0.1193 - val_accuracy: 0.9666

# %%
model.evaluate(x_test, y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.12681925976499916, 0.9622]

# %%
model.predict_classes(x_test)
# Out:
# array([7, 2, 1, ..., 4, 5, 6])

# %% [markdown]
# ## Use other optimizers

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')    
])
model.compile(optimizer="adam", loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))

# %%
model.evaluate(x_test, y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.09543165986898239, 0.9747]

# %% [markdown]
# ## Use MSE as loss

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')    
])
model.compile(optimizer="adam", loss='mse', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 7s 118us/sample - loss: 0.0162 - accuracy: 0.8903 - val_loss: 0.0092 - val_accuracy: 0.9394
# Epoch 2/10
# 60000/60000 [==============================] - 6s 107us/sample - loss: 0.0086 - accuracy: 0.9441 - val_loss: 0.0071 - val_accuracy: 0.9538
# Epoch 3/10
# 60000/60000 [==============================] - 6s 108us/sample - loss: 0.0070 - accuracy: 0.9543 - val_loss: 0.0074 - val_accuracy: 0.9494
# Epoch 4/10
# 60000/60000 [==============================] - 7s 109us/sample - loss: 0.0061 - accuracy: 0.9604 - val_loss: 0.0066 - val_accuracy: 0.9567
# Epoch 5/10
# 60000/60000 [==============================] - 6s 108us/sample - loss: 0.0057 - accuracy: 0.9628 - val_loss: 0.0059 - val_accuracy: 0.9622
# Epoch 6/10
# 60000/60000 [==============================] - 6s 107us/sample - loss: 0.0050 - accuracy: 0.9682 - val_loss: 0.0054 - val_accuracy: 0.9664
# Epoch 7/10
# 60000/60000 [==============================] - 6s 107us/sample - loss: 0.0047 - accuracy: 0.9696 - val_loss: 0.0055 - val_accuracy: 0.9640
# Epoch 8/10
# 60000/60000 [==============================] - 6s 108us/sample - loss: 0.0044 - accuracy: 0.9721 - val_loss: 0.0060 - val_accuracy: 0.9624
# Epoch 9/10
# 60000/60000 [==============================] - 7s 109us/sample - loss: 0.0042 - accuracy: 0.9734 - val_loss: 0.0050 - val_accuracy: 0.9682
# Epoch 10/10
# 60000/60000 [==============================] - 7s 109us/sample - loss: 0.0040 - accuracy: 0.9748 - val_loss: 0.0050 - val_accuracy: 0.9688

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')    
])
optimizer = tf.keras.optimizers.Adam(learning_rate=5e-4)
model.compile(optimizer=optimizer, loss='mse', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 7s 115us/sample - loss: 0.0159 - accuracy: 0.8929 - val_loss: 0.0101 - val_accuracy: 0.9323
# Epoch 2/10
# 60000/60000 [==============================] - 6s 107us/sample - loss: 0.0089 - accuracy: 0.9424 - val_loss: 0.0086 - val_accuracy: 0.9404
# Epoch 3/10
# 60000/60000 [==============================] - 7s 116us/sample - loss: 0.0069 - accuracy: 0.9558 - val_loss: 0.0059 - val_accuracy: 0.9608
# Epoch 4/10
# 60000/60000 [==============================] - 7s 115us/sample - loss: 0.0058 - accuracy: 0.9622 - val_loss: 0.0060 - val_accuracy: 0.9613
# Epoch 5/10
# 60000/60000 [==============================] - 6s 106us/sample - loss: 0.0050 - accuracy: 0.9680 - val_loss: 0.0053 - val_accuracy: 0.9643
# Epoch 6/10
# 60000/60000 [==============================] - 6s 107us/sample - loss: 0.0045 - accuracy: 0.9722 - val_loss: 0.0051 - val_accuracy: 0.9673
# Epoch 7/10
# 60000/60000 [==============================] - 6s 106us/sample - loss: 0.0042 - accuracy: 0.9732 - val_loss: 0.0045 - val_accuracy: 0.9708
# Epoch 8/10
# 60000/60000 [==============================] - 6s 107us/sample - loss: 0.0038 - accuracy: 0.9757 - val_loss: 0.0047 - val_accuracy: 0.9692
# Epoch 9/10
# 60000/60000 [==============================] - 6s 106us/sample - loss: 0.0035 - accuracy: 0.9780 - val_loss: 0.0044 - val_accuracy: 0.9719
# Epoch 10/10
# 60000/60000 [==============================] - 6s 106us/sample - loss: 0.0033 - accuracy: 0.9795 - val_loss: 0.0047 - val_accuracy: 0.9698

# %%
model.evaluate(x_test, y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.004682652213206341, 0.9698]
